# %%
import re
import pandas as pd
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
import os,sys
import tqdm
import pickle
import copy

# %%
rootPath ='D:/git/IoT_Sensors_Security_Analysis/data/perf/'
tw = 50
resultsPath = 'D:/git/IoT_Sensors_Security_Analysis/results/pi4_2G/tw_{}_turn_1/'.format(tw)
# resultsPath = 'D:/git/IoT_Sensors_Security_Analysis/results/tw_50_turn_1/'

# %%
encoded_trace_df = pd.read_pickle(resultsPath+'encoded_bow.pkl')

# %%
import torch as T
import torch.utils.data as data
import tqdm
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import time
import numpy as np
from sklearn import metrics
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.decomposition import PCA

# %%
normal = encoded_trace_df[encoded_trace_df.maltype=='normal']

# %%
def reshape_matrix(matrix_list):
    new_list = [np.array(i).reshape(-1) for i in matrix_list]
    return new_list

# %%
def padding_onehot(onehot_list, padding):
    new_list = []
    for onehot in onehot_list:
        if len(onehot) > padding:
            onehot = np.array(onehot[0:padding])
            new_list.append(onehot)
        else:
            onehot =np.pad(onehot, [(0, padding-len(onehot)), (0, 0)], mode='constant', constant_values=0)
            new_list.append(onehot)
    new_list = reshape_matrix(new_list)
    return new_list

# %%
def padding_dictencoding(dictencoding_list, padding):
    new_list = []
    for onehot in dictencoding_list:
        if len(onehot) > padding:
            onehot = np.array(onehot[0:padding])
            new_list.append(onehot)
        else:
            onehot =np.pad(onehot, [(0, padding-len(onehot))], mode='constant', constant_values=0)
            new_list.append(onehot)
    return new_list

# %%
# X = normal['frequency_features'].tolist()
# y = normal['maltype'].tolist()
# mlb = LabelBinarizer()

# y = mlb.fit_transform(y).reshape(len(y))
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.3, random_state=42)

# %%
class Autoencoder_DNN(T.nn.Module):  # input_len-32-8-32-input_len
  def __init__(self, input_len):
    super(Autoencoder_DNN, self).__init__()
    self.fc1 = T.nn.Linear(input_len, 64)
    self.fc2 = T.nn.Linear(64, 16)
    self.fc3 = T.nn.Linear(16, 8)
    self.fc4 = T.nn.Linear(8, 16)
    self.fc5 = T.nn.Linear(16, 64)
    self.fc6 = T.nn.Linear(64, input_len)

  def encode(self, x):  # input_len-32-8
    z = T.relu(self.fc1(x))
    z = T.relu(self.fc2(z)) 
    z = T.relu(self.fc3(z)) 
    return z  

  def decode(self, x):  # 8-32-input_len
    z = T.relu(self.fc4(x))
    z = T.relu(self.fc5(z)) 
    z = T.relu(self.fc6(z)) 
    return z
    
  def forward(self, x):  # 65-32-8-32-65
    z = self.encode(x) 
    z = self.decode(z) 
    return z  # in [0.0, 1.0]

# %%
def train(train_loader, val_loader, input_len):
    net = Autoencoder_DNN(input_len)
    net = net.train() 
    loss_func = T.nn.MSELoss()
    optimizer = T.optim.Adam(net.parameters(), lr=0.01)
    max_epochs = 100
    print("Starting training")
    last_val_loss = float("inf")
    patience = 0
    last_loss = 0
    for epoch in range(0, max_epochs):
        loss = 0
        if epoch > 0 and epoch % (max_epochs/10) == 0:
            print("epoch = %6d" % epoch, end="")
            print(" prev total loss = %7.4f, perv total val-loss = %7.4f" %( last_loss,val_loss))
        for curr_bat in train_loader:
            X = T.Tensor(curr_bat)
            optimizer.zero_grad()
            oupt = net(X)
            loss_obj = loss_func(oupt, X)  # note X not Y
            loss += loss_obj.item()
            loss_obj.backward()
            optimizer.step()
        last_loss = loss
        val_loss = 0
        with T.no_grad():
            for curr_bat in val_loader:
                X = T.Tensor(curr_bat)
                oupt = net(X)
                val_loss_obj = loss_func(oupt, X)  # note X not Y
                val_loss += val_loss_obj.item()
            # print(loss, val_loss)
            if val_loss < last_val_loss:
                last_val_loss = val_loss
                patience = 0
            else:
                patience += 1
        if patience >= 50:
            break               
    print("Training stop at epoch： %d" %epoch)
    return net

# %%
def find_threshold(net, X_train):
    net = net.eval()
    loss_func = T.nn.MSELoss()
    with T.no_grad():
        x_t = T.Tensor(X_train)
        y_t = net(x_t)
        y_pred = np.array([loss_func(y_t[i],x_t[i]).item() for i in range(0,len(x_t))])
    down_threshold = np.percentile(y_pred, 2.5)
    up_threshold = np.percentile(y_pred, 97.5)
    return down_threshold, up_threshold

# %%
def test(net, X, down_threshold, up_threshold):
    net = net.eval()  
    loss_func = T.nn.MSELoss()
    y_pred = []
    with T.no_grad():
        for i in range(0,len(X)):
            x = T.Tensor(X[i])
            y_t = net(x)
            t = loss_func(y_t,x).item()
            if t > down_threshold and t < up_threshold:
                y_pred.append(0)
            else:
                y_pred.append(1)
    return y_pred

# %%
# def find_threshold(net, X_train):
#     net = net.eval()
#     x_t = X_train
#     y_t = net(x_t)
#     y_pred = np.array([float(T.sum((x_t[i]-y_t[i])*(x_t[i]-y_t[i]))) for i in range(0,len(x_t))])
#     down_threshold = np.percentile(y_pred, 5)
#     up_threshold = np.percentile(y_pred, 95)
#     return down_threshold, up_threshold

# %%
# def test(net, X, down_threshold, up_threshold):
#     net = net.eval()  
#     encoded = net(X)
#     y_pred = []
#     for i in range(0,len(X)):
#         t = T.sum((X[i]-encoded[i])*(X[i]-encoded[i]))
#         if t > down_threshold and t < up_threshold:
#             y_pred.append(0)
#         else:
#             y_pred.append(1)
#     return y_pred

# %%
def train_models(feature, normal):
    X = normal[feature].tolist()
    y = normal['maltype'].tolist()
    y = np.zeros(len(X))
    # mlb = LabelBinarizer()
    
    # y = mlb.fit_transform(y).reshape(len(y))
    # h = .02  # step size in the mesh
    outliers_fraction = 0.15
    nu = 0.05
    clfs = []
    results = []
    preds = []
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.3, random_state=42)
    y_val_2 = [1 if i==0 else -1 for i in y_val]

    X_tv = []
    pca = PCA(n_components=100)
    if feature =='system calls dependency graph':
        X_train = reshape_matrix(X_train)
        X_val = reshape_matrix(X_val)    
        X_tv=[(X_train,X_val)]
        features = [feature]
    elif feature =='one hot encoding':
        X_train_150000 = padding_onehot(X_train, 150000)
        X_val_150000 = padding_onehot(X_val, 150000)
        X_train_pca = pca.fit_transform(X_train_150000)
        X_val_pca = pca.transform(X_val_150000)
        X_tv = [(X_train_pca,X_val_pca), (X_train_150000, X_val_150000)]
        features = [feature+'-pca', feature]
    elif feature =='dict index encoding':
        X_train_150000 = padding_dictencoding(X_train, 150000)
        X_val_150000 = padding_dictencoding(X_val, 150000)
        X_train_pca = pca.fit_transform(X_train_150000)
        X_val_pca = pca.transform(X_val_150000)
        # X_train_10000 = padding_dictencoding(X_train, 55000)
        # X_val_10000 = padding_dictencoding(X_val, 55000)
        X_tv = [(X_train_pca,X_val_pca),(X_train_150000,X_val_150000)]
        features = [feature+'-pca', feature]
    elif feature =='system calls hashing':
        X_tv=[(X_train,X_val)]
        features = [feature]
    else:
        X_train_pca = pca.fit_transform(X_train)
        X_val_pca = pca.transform(X_val)
        X_tv = [(X_train_pca,X_val_pca),(X_train,X_val)]
        features = [feature+'-pca', feature]

    for i,(X_train,X_val)  in enumerate(X_tv):
        feature = features[i]
        X_train = T.FloatTensor(X_train)
        X_val = T.FloatTensor(X_val)
        train_loader = data.DataLoader(X_train, batch_size=256, shuffle=False, drop_last=False, pin_memory=True, num_workers=4)
        val_loader = data.DataLoader(X_val, batch_size=256, shuffle=False, drop_last=False, num_workers=4)
        input_len = len(X_train[0])
        pred = dict()
        t1 =time.time()
        net = train(train_loader,val_loader, input_len)
        t2 =time.time()
        down_threshold, up_threshold = find_threshold(net, X_train)
        name = 'Autoencoder_DNN'
        y_pred = test(net, X_val,down_threshold, up_threshold)
        score = metrics.accuracy_score(y_val,y_pred)
        pred['valid_' + feature + '_' + name] = y_pred
        t = t2 -t1
        res = dict()
        res['Model'] = 'valid_' + feature + '_' + name
        res['Accuracy'] = score
        res['Training time'] = t
        preds.append(pred)          
        results.append(res)
        classifier = dict()
        classifier['Autoencoder_DNN'] = net
        classifier['down_threshold'] = down_threshold 
        classifier['up_threshold'] = up_threshold 
        print('Model: {}, accuracy score: {}, training time is: {} seconds'.format(res['Model'], score, t))
        clfs.append(classifier)
    return clfs, results, preds, pca

# %%
def test_models(encoded_trace_df, malware, feature, clfs, selectkmodels):
    dfs = encoded_trace_df[encoded_trace_df.maltype==malware]
    X_test = dfs[feature].tolist()
    X_tv = [] 
    if feature =='system calls dependency graph':
        X_test = reshape_matrix(X_test)    
        X_tv=[X_test]
        features = [feature]
    elif feature =='one hot encoding':
        X_test_55000 = padding_onehot(X_test, 150000)
        X_test_pca = pca.transform(X_test_55000)
        X_tv = [X_test_pca, X_test_55000]
        features = [feature+'-pca', feature]
    elif feature =='dict index encoding':
        X_test_55000 = padding_dictencoding(X_test, 150000)       
        X_test_pca = pca.transform(X_test_55000)
        X_test_10000 = padding_dictencoding(X_test, 150000)       
        X_tv = [X_test_pca, X_test_10000]
        features = [feature+'-pca', feature]
    elif feature =='system calls hashing':
        X_tv=[X_test]
        features = [feature]
    else:

        X_test_pca = pca.transform(X_test)
        X_tv = [X_test_pca, X_test]
        features = [feature+'-pca', feature]

    results = []
    preds = []
    y_test = np.ones(len(X_test))

    for i,classifier in enumerate(clfs):
        feature = features[i]
        X_test = X_tv[i]
        X_test = T.FloatTensor(X_test)
        result = []
        pred = dict()    
        name = 'Autoencoder_DNN'
        res = dict()
        net = classifier[name]
        down_threshold = classifier['down_threshold']
        up_threshold = classifier['up_threshold']
        t1 =time.time()
        y_pred = test(net, X_test, down_threshold, up_threshold)
        t2 =time.time()
        score = metrics.accuracy_score(y_test,y_pred)
        t = t2 -t1
        pred[malware +'_' + feature + '_' + name] = y_pred
        res['Model'] =malware +'_' + feature + '_' + name
        res['Accuracy'] = score
        res['Testing time'] = t
        result.append(res)
        print('Model: {}, accuracy score: {}, testing time is: {} seconds'.format( res['Model'], score, t))
        results.append(result)
        preds.append(pred)
    return results, preds

# %%
def run(device, tw):
    resultsPath = 'D:/git/IoT_Sensors_Security_Analysis/results/{}/tw_{}_turn_1/'.format(device, tw)
    encoded_trace_df = pd.read_pickle(resultsPath+'encoded_bow.pkl')
    normal = encoded_trace_df[encoded_trace_df.maltype=='normal']
    resultsdict = dict()
    predsdict = dict()
    classifiersdict = dict()
    pcas = dict()
    for feature in features:
        #train stage
        clfs, results, preds, pca = train_models(feature, normal)
        
        resultsdict[feature+'_validation'] = results
        predsdict[feature+'_validation'] = preds
        classifiersdict[feature] = clfs
        pcas[feature] = pca
        # testing stage
        for malware in malwares:
            results, preds = test_models(encoded_trace_df, malware, feature, clfs, pca)
            resultsdict[malware +'_' + feature] = results
            predsdict[malware +'_' + feature] = preds
            
    loc=open(resultsPath+'dnn_classifiers.pk','wb')
    pickle.dump(classifiersdict,loc)
    loc=open(resultsPath+'dnn_results.pk','wb')
    pickle.dump(resultsdict,loc)
    loc=open(resultsPath+'dnn_preds.pk','wb')
    pickle.dump(predsdict,loc)   
    loc=open(resultsPath+'dnn_selectkmodels.pk','wb')
    pickle.dump(pcas,loc)   

    rd = []
    for rs in resultsdict:
        if 'validation' in rs:
            for r in resultsdict[rs]:
                rd.append(r)
        else:
            for r in resultsdict[rs]:
                for s in r:
                    rd.append(s)
    rd = pd.DataFrame(rd)
    md = [i.split('_') for i in rd['Model']]
    md = pd.DataFrame(md)
    md.columns  = ['Dataset','Features','Model','Architecture']
    nrd=pd.DataFrame([md['Dataset'],md['Features'],md['Model'],md['Architecture'], rd['Accuracy']]).transpose()
    nrd.to_csv(resultsPath+'Autoencoder_DNN_results.csv',index=None)

# %%
features = ['system calls frequency' ,'system calls tfidf','system calls hashing', 'system calls dependency graph', 'one hot encoding', 'dict index encoding' ]
malwares=["delay", "disorder", "freeze", "hop", "mimic", "noise", "repeat", "spoof"]

# %%
devices = ['pi4_2G', 'pi4_4G']
tws = [50, 60, 70]
for device in devices:
    for tw in tws:
        if devices == 'pi4_2G' and tw == 50:
            continue
        else:
            run(device, tw)
# Out:
# Starting training
# epoch =     30 prev total loss = 828920.7812, perv total val-loss = 337321.2500
# epoch =     60 prev total loss = 827474.6875, perv total val-loss = 334745.7812
# Training stop at epoch： 78
# Model: valid_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.8359375, training time is: 182.56922817230225 seconds
# Starting training
# epoch =     30 prev total loss = 12822634.5000, perv total val-loss = 6146123.5000
# epoch =     60 prev total loss = 12774234.5000, perv total val-loss = 6101868.0000
# epoch =     90 prev total loss = 12773858.5000, perv total val-loss = 6101629.5000
# epoch =    120 prev total loss = 12773726.0000, perv total val-loss = 6101546.5000
# epoch =    150 prev total loss = 12773620.0000, perv total val-loss = 6101477.0000
# epoch =    180 prev total loss = 12773539.5000, perv total val-loss = 6101423.5000
# epoch =    210 prev total loss = 12773481.0000, perv total val-loss = 6101383.5000
# epoch =    240 prev total loss = 12773440.0000, perv total val-loss = 6101354.0000
# epoch =    270 prev total loss = 12773413.0000, perv total val-loss = 6101332.5000
# Training stop at epoch： 299
# Model: valid_system calls frequency_Autoencoder_DNN, accuracy score: 0.90625, training time is: 778.2956590652466 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21044/1690146738.py in <module>
#       6             continue
#       7         else:
# ----> 8             run(device, tw)
#
# ~\AppData\Local\Temp/ipykernel_21044/2061519435.py in run(device, tw)
#      17         # testing stage
#      18         for malware in malwares:
# ---> 19             results, preds = test_models(encoded_trace_df, malware, feature, clfs, pca)
#      20             resultsdict[malware +'_' + feature] = results
#      21             predsdict[malware +'_' + feature] = preds
#
# ~\AppData\Local\Temp/ipykernel_21044/2359037016.py in test_models(encoded_trace_df, malware, feature, clfs, selectkmodels)
#      23     else:
#      24
# ---> 25         X_test_pca = pca.transform(X_test)
#      26         X_tv = [X_test_pca, X_test]
#      27         features = [feature+'-pca', feature]
#
# NameError: name 'pca' is not defined

# %%
resultsdict = dict()
predsdict = dict()
classifiersdict = dict()
pcas = dict()
for feature in features:
    #train stage
    clfs, results, preds, pca = train_models(feature, normal)
    
    resultsdict[feature+'_validation'] = results
    predsdict[feature+'_validation'] = preds
    classifiersdict[feature] = clfs
    pcas[feature] = pca
    # testing stage
    for malware in malwares:
        results, preds = test_models(malware, feature, clfs, pca)
        resultsdict[malware +'_' + feature] = results
        predsdict[malware +'_' + feature] = preds
        
loc=open(resultsPath+'dnn_classifiers.pk','wb')
pickle.dump(classifiersdict,loc)
loc=open(resultsPath+'dnn_results.pk','wb')
pickle.dump(resultsdict,loc)
loc=open(resultsPath+'dnn_preds.pk','wb')
pickle.dump(predsdict,loc)   
loc=open(resultsPath+'dnn_selectkmodels.pk','wb')
pickle.dump(pcas,loc)
# Out:
# Starting training
# epoch =     30 prev total loss = 835459.3750, perv total val-loss = 335393.2812
# epoch =     60 prev total loss = 827658.4688, perv total val-loss = 334605.1875
# epoch =     90 prev total loss = 827652.0625, perv total val-loss = 334604.4062
# epoch =    120 prev total loss = 827651.7500, perv total val-loss = 334603.9375
# epoch =    150 prev total loss = 827651.5938, perv total val-loss = 334603.6250
# epoch =    180 prev total loss = 827651.5000, perv total val-loss = 334603.4062
# epoch =    210 prev total loss = 827651.4688, perv total val-loss = 334603.2812
# epoch =    240 prev total loss = 827651.4062, perv total val-loss = 334603.1562
# epoch =    270 prev total loss = 827651.4062, perv total val-loss = 334603.0938
# Training stop at epoch： 299
# Model: valid_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.8359375, training time is: 458.4078722000122 seconds
# Starting training
# epoch =     30 prev total loss = 13168792.5000, perv total val-loss = 6295819.5000
# epoch =     60 prev total loss = 13127814.0000, perv total val-loss = 6270940.5000
# epoch =     90 prev total loss = 13127555.0000, perv total val-loss = 6270809.5000
# epoch =    120 prev total loss = 13127442.5000, perv total val-loss = 6270737.5000
# epoch =    150 prev total loss = 13127374.5000, perv total val-loss = 6270692.0000
# epoch =    180 prev total loss = 13127337.5000, perv total val-loss = 6270665.5000
# epoch =    210 prev total loss = 13127317.0000, perv total val-loss = 6270649.5000
# epoch =    240 prev total loss = 13127307.5000, perv total val-loss = 6270640.5000
# epoch =    270 prev total loss = 13127302.5000, perv total val-loss = 6270635.5000
# Training stop at epoch： 299
# Model: valid_system calls frequency_Autoencoder_DNN, accuracy score: 0.90625, training time is: 458.8149631023407 seconds
# Model: delay_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.0962962962962963, testing time is: 0.020003318786621094 seconds
# Model: delay_system calls frequency_Autoencoder_DNN, accuracy score: 0.13333333333333333, testing time is: 0.02400493621826172 seconds
# Model: disorder_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.19230769230769232, testing time is: 0.007001638412475586 seconds
# Model: disorder_system calls frequency_Autoencoder_DNN, accuracy score: 0.1346153846153846, testing time is: 0.008002758026123047 seconds
# Model: freeze_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.0047169811320754715, testing time is: 0.0670161247253418 seconds
# Model: freeze_system calls frequency_Autoencoder_DNN, accuracy score: 0.06367924528301887, testing time is: 0.07301521301269531 seconds
# Model: hop_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.12994350282485875, testing time is: 0.05101203918457031 seconds
# Model: hop_system calls frequency_Autoencoder_DNN, accuracy score: 0.11581920903954802, testing time is: 0.062013864517211914 seconds
# Model: mimic_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.060714285714285714, testing time is: 0.03900909423828125 seconds
# Model: mimic_system calls frequency_Autoencoder_DNN, accuracy score: 0.26071428571428573, testing time is: 0.040007829666137695 seconds
# Model: noise_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.11163895486935867, testing time is: 0.05801248550415039 seconds
# Model: noise_system calls frequency_Autoencoder_DNN, accuracy score: 0.12826603325415678, testing time is: 0.0780174732208252 seconds
# Model: repeat_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.01643192488262911, testing time is: 0.06601572036743164 seconds
# Model: repeat_system calls frequency_Autoencoder_DNN, accuracy score: 0.011737089201877934, testing time is: 0.07401585578918457 seconds
# Model: spoof_system calls frequency-pca_Autoencoder_DNN, accuracy score: 0.012953367875647668, testing time is: 0.05301189422607422 seconds
# Model: spoof_system calls frequency_Autoencoder_DNN, accuracy score: 0.18652849740932642, testing time is: 0.06201457977294922 seconds
# Starting training
# epoch =     30 prev total loss =  0.0000, perv total val-loss =  0.0000
# Training stop at epoch： 53
# Model: valid_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.8984375, training time is: 82.68255543708801 seconds
# Starting training
# epoch =     30 prev total loss =  0.0009, perv total val-loss =  0.0004
# epoch =     60 prev total loss =  0.0009, perv total val-loss =  0.0004
# epoch =     90 prev total loss =  0.0009, perv total val-loss =  0.0004
# epoch =    120 prev total loss =  0.0009, perv total val-loss =  0.0004
# Training stop at epoch： 139
# Model: valid_system calls tfidf_Autoencoder_DNN, accuracy score: 0.875, training time is: 214.07604122161865 seconds
# Model: delay_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.9703703703703703, testing time is: 0.023006200790405273 seconds
# Model: delay_system calls tfidf_Autoencoder_DNN, accuracy score: 0.15555555555555556, testing time is: 0.03200840950012207 seconds
# Model: disorder_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.8846153846153846, testing time is: 0.008001089096069336 seconds
# Model: disorder_system calls tfidf_Autoencoder_DNN, accuracy score: 0.7692307692307693, testing time is: 0.01000213623046875 seconds
# Model: freeze_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.0330188679245283, testing time is: 0.06801486015319824 seconds
# Model: freeze_system calls tfidf_Autoencoder_DNN, accuracy score: 0.8325471698113207, testing time is: 0.07501721382141113 seconds
# Model: hop_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.07344632768361582, testing time is: 0.053012847900390625 seconds
# Model: hop_system calls tfidf_Autoencoder_DNN, accuracy score: 0.0903954802259887, testing time is: 0.06801557540893555 seconds
# Model: mimic_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.275, testing time is: 0.0400087833404541 seconds
# Model: mimic_system calls tfidf_Autoencoder_DNN, accuracy score: 0.25, testing time is: 0.039008378982543945 seconds
# Model: noise_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.09501187648456057, testing time is: 0.06701421737670898 seconds
# Model: noise_system calls tfidf_Autoencoder_DNN, accuracy score: 0.1021377672209026, testing time is: 0.07301664352416992 seconds
# Model: repeat_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.02112676056338028, testing time is: 0.061013221740722656 seconds
# Model: repeat_system calls tfidf_Autoencoder_DNN, accuracy score: 0.8755868544600939, testing time is: 0.0690147876739502 seconds
# Model: spoof_system calls tfidf-pca_Autoencoder_DNN, accuracy score: 0.16580310880829016, testing time is: 0.05701255798339844 seconds
# Model: spoof_system calls tfidf_Autoencoder_DNN, accuracy score: 0.7875647668393783, testing time is: 0.06501436233520508 seconds
# Starting training
# epoch =     30 prev total loss =  0.0202, perv total val-loss =  0.0101
# epoch =     60 prev total loss =  0.0202, perv total val-loss =  0.0101
# epoch =     90 prev total loss =  0.0202, perv total val-loss =  0.0101
# epoch =    120 prev total loss =  0.0202, perv total val-loss =  0.0101
# Training stop at epoch： 122
# Model: valid_system calls hashing_Autoencoder_DNN, accuracy score: 0.859375, training time is: 190.0886583328247 seconds
# Model: delay_system calls hashing_Autoencoder_DNN, accuracy score: 0.7185185185185186, testing time is: 0.01900458335876465 seconds
# Model: disorder_system calls hashing_Autoencoder_DNN, accuracy score: 0.8653846153846154, testing time is: 0.0060007572174072266 seconds
# Model: freeze_system calls hashing_Autoencoder_DNN, accuracy score: 0.8985849056603774, testing time is: 0.06301331520080566 seconds
# Model: hop_system calls hashing_Autoencoder_DNN, accuracy score: 0.0847457627118644, testing time is: 0.04901123046875 seconds
# Model: mimic_system calls hashing_Autoencoder_DNN, accuracy score: 0.26785714285714285, testing time is: 0.038008928298950195 seconds
# Model: noise_system calls hashing_Autoencoder_DNN, accuracy score: 0.0997624703087886, testing time is: 0.0490114688873291 seconds
# Model: repeat_system calls hashing_Autoencoder_DNN, accuracy score: 0.9694835680751174, testing time is: 0.05401110649108887 seconds
# Model: spoof_system calls hashing_Autoencoder_DNN, accuracy score: 0.9248704663212435, testing time is: 0.04701066017150879 seconds
# Starting training
# epoch =     30 prev total loss = 107032.6719, perv total val-loss = 53526.8555
# Training stop at epoch： 51
# Model: valid_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.84375, training time is: 79.3388044834137 seconds
# Model: delay_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.17037037037037037, testing time is: 0.024005651473999023 seconds
# Model: disorder_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.17307692307692307, testing time is: 0.007001638412475586 seconds
# Model: freeze_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.5047169811320755, testing time is: 0.06401515007019043 seconds
# Model: hop_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.11016949152542373, testing time is: 0.05301213264465332 seconds
# Model: mimic_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.2857142857142857, testing time is: 0.03700876235961914 seconds
# Model: noise_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.15676959619952494, testing time is: 0.05501222610473633 seconds
# Model: repeat_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.4835680751173709, testing time is: 0.057013750076293945 seconds
# Model: spoof_system calls dependency graph_Autoencoder_DNN, accuracy score: 0.5518134715025906, testing time is: 0.05501222610473633 seconds
# Starting training
# epoch =     30 prev total loss = 1257.9304, perv total val-loss = 374.1624
# epoch =     60 prev total loss = 1242.4636, perv total val-loss = 374.4210
# Training stop at epoch： 85
# Model: valid_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.2578125, training time is: 124.83401298522949 seconds
# Starting training
# epoch =     30 prev total loss =  0.0912, perv total val-loss =  0.0450
# epoch =     60 prev total loss =  0.0912, perv total val-loss =  0.0450
# Training stop at epoch： 87
# Model: valid_one hot encoding_Autoencoder_DNN, accuracy score: 0.8125, training time is: 3579.3585612773895 seconds
# Model: delay_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.7851851851851852, testing time is: 0.01600360870361328 seconds
# Model: delay_one hot encoding_Autoencoder_DNN, accuracy score: 0.15555555555555556, testing time is: 56.59274673461914 seconds
# Model: disorder_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.6730769230769231, testing time is: 0.007001161575317383 seconds
# Model: disorder_one hot encoding_Autoencoder_DNN, accuracy score: 0.17307692307692307, testing time is: 21.722874879837036 seconds
# Model: freeze_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.8679245283018868, testing time is: 0.06601524353027344 seconds
# Model: freeze_one hot encoding_Autoencoder_DNN, accuracy score: 0.14622641509433962, testing time is: 180.38859248161316 seconds
# Model: hop_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.7966101694915254, testing time is: 0.05201148986816406 seconds
# Model: hop_one hot encoding_Autoencoder_DNN, accuracy score: 0.12429378531073447, testing time is: 149.5036404132843 seconds
# Model: mimic_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.825, testing time is: 0.03500676155090332 seconds
# Model: mimic_one hot encoding_Autoencoder_DNN, accuracy score: 0.2892857142857143, testing time is: 115.26085472106934 seconds
# Model: noise_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.7980997624703088, testing time is: 0.062014102935791016 seconds
# Model: noise_one hot encoding_Autoencoder_DNN, accuracy score: 0.16389548693586697, testing time is: 205.4359109401703 seconds
# Model: repeat_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.8802816901408451, testing time is: 0.07001543045043945 seconds
# Model: repeat_one hot encoding_Autoencoder_DNN, accuracy score: 0.0539906103286385, testing time is: 185.89993476867676 seconds
# Model: spoof_one hot encoding-pca_Autoencoder_DNN, accuracy score: 0.9041450777202072, testing time is: 0.057012081146240234 seconds
# Model: spoof_one hot encoding_Autoencoder_DNN, accuracy score: 0.24870466321243523, testing time is: 180.65571641921997 seconds
# Starting training
# epoch =     30 prev total loss = 4371.0081, perv total val-loss = 1495.5239
# epoch =     60 prev total loss = 4314.8080, perv total val-loss = 1496.0145
# Training stop at epoch： 87
# Model: valid_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.8671875, training time is: 136.32244420051575 seconds
# Starting training
# epoch =     30 prev total loss = 11.5067, perv total val-loss =  5.9671
# epoch =     60 prev total loss = 11.2470, perv total val-loss =  5.8281
# epoch =     90 prev total loss = 11.2464, perv total val-loss =  5.8289
# Training stop at epoch： 97
# Model: valid_dict index encoding_Autoencoder_DNN, accuracy score: 0.890625, training time is: 397.13781237602234 seconds
# Model: delay_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.837037037037037, testing time is: 0.018004179000854492 seconds
# Model: delay_dict index encoding_Autoencoder_DNN, accuracy score: 0.4, testing time is: 3.8628673553466797 seconds
# Model: disorder_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.8269230769230769, testing time is: 0.007001638412475586 seconds
# Model: disorder_dict index encoding_Autoencoder_DNN, accuracy score: 0.40384615384615385, testing time is: 1.4603288173675537 seconds
# Model: freeze_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.8679245283018868, testing time is: 0.06401491165161133 seconds
# Model: freeze_dict index encoding_Autoencoder_DNN, accuracy score: 0.07311320754716981, testing time is: 11.767641067504883 seconds
# Model: hop_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.12146892655367232, testing time is: 0.05101156234741211 seconds
# Model: hop_dict index encoding_Autoencoder_DNN, accuracy score: 0.08757062146892655, testing time is: 9.691174030303955 seconds
# Model: mimic_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.3142857142857143, testing time is: 0.036008358001708984 seconds
# Model: mimic_dict index encoding_Autoencoder_DNN, accuracy score: 0.2892857142857143, testing time is: 8.183835744857788 seconds
# Model: noise_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.14251781472684086, testing time is: 0.062014102935791016 seconds
# Model: noise_dict index encoding_Autoencoder_DNN, accuracy score: 0.10926365795724466, testing time is: 11.75663709640503 seconds
# Model: repeat_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.8356807511737089, testing time is: 0.06901431083679199 seconds
# Model: repeat_dict index encoding_Autoencoder_DNN, accuracy score: 0.011737089201877934, testing time is: 12.205501317977905 seconds
# Model: spoof_dict index encoding-pca_Autoencoder_DNN, accuracy score: 0.8238341968911918, testing time is: 0.056012630462646484 seconds
# Model: spoof_dict index encoding_Autoencoder_DNN, accuracy score: 0.17875647668393782, testing time is: 10.493388891220093 seconds

# %%
rd = []
for rs in resultsdict:
    if 'validation' in rs:
        for r in resultsdict[rs]:
            rd.append(r)
    else:
        for r in resultsdict[rs]:
            for s in r:
                rd.append(s)

# %%
rd = pd.DataFrame(rd)

# %%
md = [i.split('_') for i in rd['Model']]
md = pd.DataFrame(md)

# %%
md
# Out:
#            0                           1            2    3
# 0      valid  system calls frequency-pca  Autoencoder  DNN
# 1      valid      system calls frequency  Autoencoder  DNN
# 2      delay  system calls frequency-pca  Autoencoder  DNN
# 3      delay      system calls frequency  Autoencoder  DNN
# 4   disorder  system calls frequency-pca  Autoencoder  DNN
# ..       ...                         ...          ...  ...
# 85     noise         dict index encoding  Autoencoder  DNN
# 86    repeat     dict index encoding-pca  Autoencoder  DNN
# 87    repeat         dict index encoding  Autoencoder  DNN
# 88     spoof     dict index encoding-pca  Autoencoder  DNN
# 89     spoof         dict index encoding  Autoencoder  DNN
#
# [90 rows x 4 columns]

# %%
md.columns  = ['Dataset','Features','Model','Architecture']

# %%
nrd=pd.DataFrame([md['Dataset'],md['Features'],md['Model'],md['Architecture'], rd['Accuracy']]).transpose()

# %%
nrd
# Out:
#      Dataset                    Features        Model Architecture  Accuracy
# 0      valid  system calls frequency-pca  Autoencoder          DNN  0.835938
# 1      valid      system calls frequency  Autoencoder          DNN   0.90625
# 2      delay  system calls frequency-pca  Autoencoder          DNN  0.096296
# 3      delay      system calls frequency  Autoencoder          DNN  0.133333
# 4   disorder  system calls frequency-pca  Autoencoder          DNN  0.192308
# ..       ...                         ...          ...          ...       ...
# 85     noise         dict index encoding  Autoencoder          DNN  0.109264
# 86    repeat     dict index encoding-pca  Autoencoder          DNN  0.835681
# 87    repeat         dict index encoding  Autoencoder          DNN  0.011737
# 88     spoof     dict index encoding-pca  Autoencoder          DNN  0.823834
# 89     spoof         dict index encoding  Autoencoder          DNN  0.178756
#
# [90 rows x 5 columns]

# %%
nrd.to_csv(resultsPath+'Autoencoder_DNN_results.csv',index=None)
